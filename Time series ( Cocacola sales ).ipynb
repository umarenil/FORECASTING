# %% [markdown]
# # Time series ( Cocacola sales )

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 3A3B-B1C3
#
#  Directory of C:\Users\Dell\EXCELR\Assignment\Time Series
#
# 16-12-2022  22:57    <DIR>          .
# 13-12-2022  19:31    <DIR>          ..
# 15-12-2022  16:53    <DIR>          .ipynb_checkpoints
# 30-11-2022  12:10             9,559 Airlines+Data.xlsx
# 30-11-2022  12:10             9,422 CocaCola_Sales_Rawdata.xlsx
# 15-12-2022  21:32               739 dataset.csv
# 30-11-2022  12:10               233 Problem_statement.txt
# 15-12-2022  18:02           762,258 Time Forecasting( Airlines Passengers data ).ipynb
# 16-12-2022  22:57           200,680 Time series ( Cocacola sales ).ipynb
# 15-12-2022  21:32               140 validation.csv
#                7 File(s)        983,031 bytes
#                3 Dir(s)  182,061,023,232 bytes free

# %%
print(open("Problem_statement.txt").read())
# Out:
# Forecast the CocaCola prices and Airlines Passengers data set. Prepare a document for each model explaining
# how many dummy variables you have created and RMSE value for each model. Finally which model you will use for
# Forecasting.

# %%
data = pd.read_excel("CocaCola_Sales_Rawdata.xlsx")
data
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %% [markdown]
# ### EDA

# %%
data.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Sales'}>]], dtype=object)

# %%
data.plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from statsmodels.tsa.stattools import adfuller

print ('Results of Dickey-Fuller Test:')
dftest = adfuller(data['Sales'], autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  1.309421
# p-value                         0.996661
# #Lags Used                      7.000000
# Number of Observations Used    34.000000
# Critical Value (1%)            -3.639224
# Critical Value (5%)            -2.951230
# Critical Value (10%)           -2.614447
# dtype: float64

# %%
len(data)
# Out:
# 42

# %%
data['quarter']=0
for i in range(42):
    n=data['Quarter'][i]
    data['quarter'][i]=n[0:2]

# %%
data
# Out:
#    Quarter        Sales quarter
# 0    Q1_86  1734.827000      Q1
# 1    Q2_86  2244.960999      Q2
# 2    Q3_86  2533.804993      Q3
# 3    Q4_86  2154.962997      Q4
# 4    Q1_87  1547.818996      Q1
# 5    Q2_87  2104.411995      Q2
# 6    Q3_87  2014.362999      Q3
# 7    Q4_87  1991.746998      Q4
# 8    Q1_88  1869.049999      Q1
# 9    Q2_88  2313.631996      Q2
# 10   Q3_88  2128.320000      Q3
# 11   Q4_88  2026.828999      Q4
# 12   Q1_89  1910.603996      Q1
# 13   Q2_89  2331.164993      Q2
# 14   Q3_89  2206.549995      Q3
# 15   Q4_89  2173.967995      Q4
# 16   Q1_90  2148.278000      Q1
# 17   Q2_90  2739.307999      Q2
# 18   Q3_90  2792.753998      Q3
# 19   Q4_90  2556.009995      Q4
# 20   Q1_91  2480.973999      Q1
# 21   Q2_91  3039.522995      Q2
# 22   Q3_91  3172.115997      Q3
# 23   Q4_91  2879.000999      Q4
# 24   Q1_92  2772.000000      Q1
# 25   Q2_92  3550.000000      Q2
# 26   Q3_92  3508.000000      Q3
# 27   Q4_92  3243.859993      Q4
# 28   Q1_93  3056.000000      Q1
# 29   Q2_93  3899.000000      Q2
# 30   Q3_93  3629.000000      Q3
# 31   Q4_93  3373.000000      Q4
# 32   Q1_94  3352.000000      Q1
# 33   Q2_94  4342.000000      Q2
# 34   Q3_94  4461.000000      Q3
# 35   Q4_94  4017.000000      Q4
# 36   Q1_95  3854.000000      Q1
# 37   Q2_95  4936.000000      Q2
# 38   Q3_95  4895.000000      Q3
# 39   Q4_95  4333.000000      Q4
# 40   Q1_96  4194.000000      Q1
# 41   Q2_96  5253.000000      Q2

# %%
data['quarter'].value_counts()
# Out:
# Q1    11
# Q2    11
# Q3    10
# Q4    10
# Name: quarter, dtype: int64

# %% [markdown]
# #### Creating dummy columns

# %%
df_dummies=pd.DataFrame(pd.get_dummies(data['quarter']),columns=['Q1','Q2','Q3','Q4'])
cc=pd.concat([data,df_dummies],axis= 1)

# %%
cc
# Out:
#    Quarter        Sales quarter  Q1  Q2  Q3  Q4
# 0    Q1_86  1734.827000      Q1   1   0   0   0
# 1    Q2_86  2244.960999      Q2   0   1   0   0
# 2    Q3_86  2533.804993      Q3   0   0   1   0
# 3    Q4_86  2154.962997      Q4   0   0   0   1
# 4    Q1_87  1547.818996      Q1   1   0   0   0
# 5    Q2_87  2104.411995      Q2   0   1   0   0
# 6    Q3_87  2014.362999      Q3   0   0   1   0
# 7    Q4_87  1991.746998      Q4   0   0   0   1
# 8    Q1_88  1869.049999      Q1   1   0   0   0
# 9    Q2_88  2313.631996      Q2   0   1   0   0
# 10   Q3_88  2128.320000      Q3   0   0   1   0
# 11   Q4_88  2026.828999      Q4   0   0   0   1
# 12   Q1_89  1910.603996      Q1   1   0   0   0
# 13   Q2_89  2331.164993      Q2   0   1   0   0
# 14   Q3_89  2206.549995      Q3   0   0   1   0
# 15   Q4_89  2173.967995      Q4   0   0   0   1
# 16   Q1_90  2148.278000      Q1   1   0   0   0
# 17   Q2_90  2739.307999      Q2   0   1   0   0
# 18   Q3_90  2792.753998      Q3   0   0   1   0
# 19   Q4_90  2556.009995      Q4   0   0   0   1
# 20   Q1_91  2480.973999      Q1   1   0   0   0
# 21   Q2_91  3039.522995      Q2   0   1   0   0
# 22   Q3_91  3172.115997      Q3   0   0   1   0
# 23   Q4_91  2879.000999      Q4   0   0   0   1
# 24   Q1_92  2772.000000      Q1   1   0   0   0
# 25   Q2_92  3550.000000      Q2   0   1   0   0
# 26   Q3_92  3508.000000      Q3   0   0   1   0
# 27   Q4_92  3243.859993      Q4   0   0   0   1
# 28   Q1_93  3056.000000      Q1   1   0   0   0
# 29   Q2_93  3899.000000      Q2   0   1   0   0
# 30   Q3_93  3629.000000      Q3   0   0   1   0
# 31   Q4_93  3373.000000      Q4   0   0   0   1
# 32   Q1_94  3352.000000      Q1   1   0   0   0
# 33   Q2_94  4342.000000      Q2   0   1   0   0
# 34   Q3_94  4461.000000      Q3   0   0   1   0
# 35   Q4_94  4017.000000      Q4   0   0   0   1
# 36   Q1_95  3854.000000      Q1   1   0   0   0
# 37   Q2_95  4936.000000      Q2   0   1   0   0
# 38   Q3_95  4895.000000      Q3   0   0   1   0
# 39   Q4_95  4333.000000      Q4   0   0   0   1
# 40   Q1_96  4194.000000      Q1   1   0   0   0
# 41   Q2_96  5253.000000      Q2   0   1   0   0

# %%
cc['t'] = np.arange(1,43)
cc['t_squared'] = cc['t']**2
cc["Sales_log"] =np.log(data['Sales'])

# %%
cc
# Out:
#    Quarter        Sales quarter  Q1  Q2  Q3  Q4   t  t_squared  Sales_log
# 0    Q1_86  1734.827000      Q1   1   0   0   0   1          1   7.458663
# 1    Q2_86  2244.960999      Q2   0   1   0   0   2          4   7.716443
# 2    Q3_86  2533.804993      Q3   0   0   1   0   3          9   7.837477
# 3    Q4_86  2154.962997      Q4   0   0   0   1   4         16   7.675529
# 4    Q1_87  1547.818996      Q1   1   0   0   0   5         25   7.344602
# 5    Q2_87  2104.411995      Q2   0   1   0   0   6         36   7.651791
# 6    Q3_87  2014.362999      Q3   0   0   1   0   7         49   7.608058
# 7    Q4_87  1991.746998      Q4   0   0   0   1   8         64   7.596767
# 8    Q1_88  1869.049999      Q1   1   0   0   0   9         81   7.533186
# 9    Q2_88  2313.631996      Q2   0   1   0   0  10        100   7.746574
# 10   Q3_88  2128.320000      Q3   0   0   1   0  11        121   7.663088
# 11   Q4_88  2026.828999      Q4   0   0   0   1  12        144   7.614228
# 12   Q1_89  1910.603996      Q1   1   0   0   0  13        169   7.555175
# 13   Q2_89  2331.164993      Q2   0   1   0   0  14        196   7.754123
# 14   Q3_89  2206.549995      Q3   0   0   1   0  15        225   7.699185
# 15   Q4_89  2173.967995      Q4   0   0   0   1  16        256   7.684309
# 16   Q1_90  2148.278000      Q1   1   0   0   0  17        289   7.672422
# 17   Q2_90  2739.307999      Q2   0   1   0   0  18        324   7.915461
# 18   Q3_90  2792.753998      Q3   0   0   1   0  19        361   7.934783
# 19   Q4_90  2556.009995      Q4   0   0   0   1  20        400   7.846203
# 20   Q1_91  2480.973999      Q1   1   0   0   0  21        441   7.816407
# 21   Q2_91  3039.522995      Q2   0   1   0   0  22        484   8.019456
# 22   Q3_91  3172.115997      Q3   0   0   1   0  23        529   8.062154
# 23   Q4_91  2879.000999      Q4   0   0   0   1  24        576   7.965199
# 24   Q1_92  2772.000000      Q1   1   0   0   0  25        625   7.927324
# 25   Q2_92  3550.000000      Q2   0   1   0   0  26        676   8.174703
# 26   Q3_92  3508.000000      Q3   0   0   1   0  27        729   8.162801
# 27   Q4_92  3243.859993      Q4   0   0   0   1  28        784   8.084519
# 28   Q1_93  3056.000000      Q1   1   0   0   0  29        841   8.024862
# 29   Q2_93  3899.000000      Q2   0   1   0   0  30        900   8.268475
# 30   Q3_93  3629.000000      Q3   0   0   1   0  31        961   8.196712
# 31   Q4_93  3373.000000      Q4   0   0   0   1  32       1024   8.123558
# 32   Q1_94  3352.000000      Q1   1   0   0   0  33       1089   8.117312
# 33   Q2_94  4342.000000      Q2   0   1   0   0  34       1156   8.376090
# 34   Q3_94  4461.000000      Q3   0   0   1   0  35       1225   8.403128
# 35   Q4_94  4017.000000      Q4   0   0   0   1  36       1296   8.298291
# 36   Q1_95  3854.000000      Q1   1   0   0   0  37       1369   8.256867
# 37   Q2_95  4936.000000      Q2   0   1   0   0  38       1444   8.504311
# 38   Q3_95  4895.000000      Q3   0   0   1   0  39       1521   8.495970
# 39   Q4_95  4333.000000      Q4   0   0   0   1  40       1600   8.374015
# 40   Q1_96  4194.000000      Q1   1   0   0   0  41       1681   8.341410
# 41   Q2_96  5253.000000      Q2   0   1   0   0  42       1764   8.566555

# %%
train =cc.head(32)
test =cc.tail(10)

# %% [markdown]
# #### Creating Models

# %%
from sklearn.metrics import mean_squared_error
import statsmodels.formula.api as smf

# %% [markdown]
# #### Linear Model

# %%
linear_model =smf.ols("Sales~t",data =train).fit()
linear_pred = pd.Series(linear_model.predict(test['t']))
linear_rmse =np.sqrt(mean_squared_error(np.array(test['Sales']),np.array(linear_pred)))
linear_rmse
# Out:
# 752.9233932767132

# %% [markdown]
# #### Quadratic Model

# %%
quad_model =smf.ols("Sales~t+t_squared",data=train).fit()
quad_pred = pd.Series(quad_model.predict(test[['t','t_squared']]))
quad_rmse =np.sqrt(mean_squared_error(np.array(test['Sales']),np.array(quad_pred)))
quad_rmse
# Out:
# 457.7357355407399

# %% [markdown]
# #### Exponential model

# %%
exp_model  =smf.ols("Sales_log~t",data=train).fit()
exp_pred =pd.Series(exp_model.predict(test['t']))
exp_rmse =np.sqrt(mean_squared_error(np.array(test['Sales']),np.array(exp_pred)))
exp_rmse
# Out:
# 4387.940544839098

# %% [markdown]
# #### Table

# %%
dd = {"MODEL":pd.Series(["rmse_linear","rmse_exp","rmse_quad"]),"RMSE_Values":pd.Series([linear_rmse,exp_rmse,quad_rmse,])}
table_rmse=pd.DataFrame(dd)
table_rmse.sort_values(['RMSE_Values'])
# Out:
#          MODEL  RMSE_Values
# 2    rmse_quad   457.735736
# 0  rmse_linear   752.923393
# 1     rmse_exp  4387.940545

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 3A3B-B1C3
#
#  Directory of C:\Users\Dell\EXCELR\Assignment\Time Series
#
# 16-12-2022  22:57    <DIR>          .
# 13-12-2022  19:31    <DIR>          ..
# 15-12-2022  16:53    <DIR>          .ipynb_checkpoints
# 30-11-2022  12:10             9,559 Airlines+Data.xlsx
# 30-11-2022  12:10             9,422 CocaCola_Sales_Rawdata.xlsx
# 15-12-2022  21:32               739 dataset.csv
# 30-11-2022  12:10               233 Problem_statement.txt
# 15-12-2022  18:02           762,258 Time Forecasting( Airlines Passengers data ).ipynb
# 16-12-2022  22:57           200,680 Time series ( Cocacola sales ).ipynb
# 15-12-2022  21:32               140 validation.csv
#                7 File(s)        983,031 bytes
#                3 Dir(s)  182,060,609,536 bytes free

# %%
data = pd.read_excel("CocaCola_Sales_Rawdata.xlsx",header=0,index_col=0, parse_dates=True)
data.head()
# Out:
#                Sales
# Quarter
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996

# %%
# separate out a validation dataset
split_point = len(data) - 10
dataset , validation = data[0:split_point], data[split_point:]
print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
dataset.to_csv('dataset.csv', header=False)
validation.to_csv('validation.csv', header=False)
# Out:
# Dataset 32, Validation 10

# %%
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from math import sqrt

train = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True)

train
# Out:
# 0
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996
# Q2_87    2104.411995
# Q3_87    2014.362999
# Q4_87    1991.746998
# Q1_88    1869.049999
# Q2_88    2313.631996
# Q3_88    2128.320000
# Q4_88    2026.828999
# Q1_89    1910.603996
# Q2_89    2331.164993
# Q3_89    2206.549995
# Q4_89    2173.967995
# Q1_90    2148.278000
# Q2_90    2739.307999
# Q3_90    2792.753998
# Q4_90    2556.009995
# Q1_91    2480.973999
# Q2_91    3039.522995
# Q3_91    3172.115997
# Q4_91    2879.000999
# Q1_92    2772.000000
# Q2_92    3550.000000
# Q3_92    3508.000000
# Q4_92    3243.859993
# Q1_93    3056.000000
# Q2_93    3899.000000
# Q3_93    3629.000000
# Q4_93    3373.000000
# Name: 1, dtype: float64

# %%
X = train.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]

# %%
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    yhat = history[-1]
    predictions.append(yhat)
# observation
    obs = test[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%.3f' % (yhat, obs))
# report performance
rmse = sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)
# Out:
# >Predicted=2173.968, Expected=2148.278
# >Predicted=2148.278, Expected=2739.308
# >Predicted=2739.308, Expected=2792.754
# >Predicted=2792.754, Expected=2556.010
# >Predicted=2556.010, Expected=2480.974
# >Predicted=2480.974, Expected=3039.523
# >Predicted=3039.523, Expected=3172.116
# >Predicted=3172.116, Expected=2879.001
# >Predicted=2879.001, Expected=2772.000
# >Predicted=2772.000, Expected=3550.000
# >Predicted=3550.000, Expected=3508.000
# >Predicted=3508.000, Expected=3243.860
# >Predicted=3243.860, Expected=3056.000
# >Predicted=3056.000, Expected=3899.000
# >Predicted=3899.000, Expected=3629.000
# >Predicted=3629.000, Expected=3373.000
# RMSE: 387.510

# %%
data = {"MODEL":pd.Series(["rmse_linear","rmse_exp","rmse_quad","RMSE_ARIMA"]),"RMSE_Values":pd.Series([linear_rmse,exp_rmse,quad_rmse,rmse])}
table_rmse=pd.DataFrame(data)
table_rmse.sort_values(['RMSE_Values'])
# Out:
#          MODEL  RMSE_Values
# 3   RMSE_ARIMA   387.510403
# 2    rmse_quad   457.735736
# 0  rmse_linear   752.923393
# 1     rmse_exp  4387.940545

# %% [markdown]
# ### grid search ARIMA parameters for a time series

# %%
import warnings
from pandas import read_csv
from statsmodels.tsa.arima.model import ARIMA     #from statsmodels.tsa.arima_model import ARIMA  
from sklearn.metrics import mean_squared_error
from math import sqrt


# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, arima_order):
# prepare training dataset
    X = X.astype('float32')
    train_size = int(len(X) * 0.80)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]
# make predictions
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
# model_fit = model.fit(disp=0)
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
# calculate out of sample error
    rmse = sqrt(mean_squared_error(test, predictions))
    return rmse

# %% [markdown]
# #### evaluate combinations of p, d and q values for an ARIMA model

# %%
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float('inf'), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    rmse = evaluate_arima_model(train, order)
                    if rmse < best_score:
                        best_score, best_cfg = rmse, order
                    print('ARIMA%s RMSE=%.3f' % (order,rmse))
                except Exception as e :
                    print(e)
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# %% [markdown]
# #### load dataset

# %%
train = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True)
# evaluate parameters
p_values = range(0, 10)
d_values = range(0, 10)
q_values = range(0, 10)
warnings.filterwarnings("ignore")
evaluate_models(train.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=1067.042
# ARIMA(0, 0, 1) RMSE=758.185
# ARIMA(0, 0, 2) RMSE=470.798
# ARIMA(0, 0, 3) RMSE=496.581
# ARIMA(0, 0, 4) RMSE=447.404
# ARIMA(0, 0, 5) RMSE=388.846
# ARIMA(0, 0, 6) RMSE=389.619
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# ARIMA(0, 1, 0) RMSE=472.258
# ARIMA(0, 1, 1) RMSE=421.994
# ARIMA(0, 1, 2) RMSE=423.073
# ARIMA(0, 1, 3) RMSE=379.744
# ARIMA(0, 1, 4) RMSE=244.736
# ARIMA(0, 1, 5) RMSE=241.921
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# ARIMA(0, 2, 0) RMSE=737.992
# ARIMA(0, 2, 1) RMSE=474.387
# ARIMA(0, 2, 2) RMSE=376.800
# ARIMA(0, 2, 3) RMSE=426.953
# ARIMA(0, 2, 4) RMSE=346.183
# ARIMA(0, 2, 5) RMSE=237.890
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# ARIMA(0, 3, 0) RMSE=1231.692
# ARIMA(0, 3, 1) RMSE=751.379
# ARIMA(0, 3, 2) RMSE=506.284
# ARIMA(0, 3, 3) RMSE=433.682
# ARIMA(0, 3, 4) RMSE=356.825
# ARIMA(0, 3, 5) RMSE=405.907
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# ARIMA(0, 3, 9) RMSE=299.342
# ARIMA(0, 4, 0) RMSE=2135.031
# ARIMA(0, 4, 1) RMSE=1253.476
# ARIMA(0, 4, 2) RMSE=795.080
# ARIMA(0, 4, 3) RMSE=653.470
# ARIMA(0, 4, 4) RMSE=495.235
# ARIMA(0, 4, 5) RMSE=679.857
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# ARIMA(0, 4, 9) RMSE=378.586
# ARIMA(0, 5, 0) RMSE=3605.227
# ARIMA(0, 5, 1) RMSE=2170.399
# ARIMA(0, 5, 2) RMSE=1296.891
# ARIMA(0, 5, 3) RMSE=826.120
# ARIMA(0, 5, 4) RMSE=577.023
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# ARIMA(0, 5, 9) RMSE=433.479
# ARIMA(0, 6, 0) RMSE=5933.439
# ARIMA(0, 6, 1) RMSE=3658.744
# ARIMA(0, 6, 2) RMSE=2239.437
# ARIMA(0, 6, 3) RMSE=1372.391
# ARIMA(0, 6, 4) RMSE=873.119
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# ARIMA(0, 6, 8) RMSE=1292.777
# ARIMA(0, 6, 9) RMSE=922.769
# ARIMA(0, 7, 0) RMSE=10094.433
# ARIMA(0, 7, 1) RMSE=6016.288
# ARIMA(0, 7, 2) RMSE=3801.546
# ARIMA(0, 7, 3) RMSE=2371.749
# ARIMA(0, 7, 4) RMSE=1515.044
# Input contains NaN.
# Input contains NaN.
# Input contains NaN.
# ARIMA(0,
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(3, 8, 8) RMSE=1608.418
# ARIMA(3, 8, 9) RMSE=1682.867
# ARIMA(3, 9, 0) RMSE=8031.164
# ARIMA(3, 9, 1) RMSE=5525.240
# ARIMA(3, 9, 2) RMSE=41458930070.296
# ARIMA(3, 9, 3) RMSE=2324.912
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(3, 9, 7) RMSE=2401.391
# ARIMA(3, 9, 8) RMSE=2381.528
# ARIMA(3, 9, 9) RMSE=3427.337
# ARIMA(4, 0, 0) RMSE=355.614
# ARIMA(4, 0, 1) RMSE=266.334
# ARIMA(4, 0, 2) RMSE=229.297
# ARIMA(4, 0, 3) RMSE=226.935
# ARIMA(4, 0, 4) RMSE=245.649
# ARIMA(4, 0, 5) RMSE=169.157
# ARIMA(4, 0, 6) RMSE=552.253
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(4, 1, 0) RMSE=160.862
# ARIMA(4, 1, 1) RMSE=174.409
# ARIMA(4, 1, 2) RMSE=180.818
# ARIMA(4, 1, 3) RMSE=141.831
# ARIMA(4, 1, 4) RMSE=1346.846
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(4, 2, 0) RMSE=159.074
# ARIMA(4, 2, 1) RMSE=155.738
# ARIMA(4, 2, 2) RMSE=159.055
# ARIMA(4, 2, 3) RMSE=1125.183
# ARIMA(4, 2, 4) RMSE=1329.357
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# ARIMA(4, 3, 0) RMSE=200.602
# ARIMA(4, 3, 1) RMSE=164.737
# ARIMA(4, 3, 2) RMSE=1333.290
# ARIMA(4, 3, 3) RMSE=178.226
# LU decomposition error.
# ARIMA(4, 3, 5) RMSE=39666.162
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(4, 3, 9) RMSE=353.741
# ARIMA(4, 4, 0) RMSE=292.675
# ARIMA(4, 4, 1) RMSE=213.690
# LU decomposition error.
# ARIMA(4, 4, 3) RMSE=602812.863
# ARIMA(4, 4, 4) RMSE=1344.487
# ARIMA(4, 4, 5) RMSE=124.738
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(4, 4, 9) RMSE=539.951
# ARIMA(4, 5, 0) RMSE=518.692
# ARIMA(4, 5, 1) RMSE=328.264
# ARIMA(4, 5, 2) RMSE=235.721
# LU decomposition error.
# ARIMA(4, 5, 4) RMSE=3826119.470
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# ARIMA(4, 5, 9) RMSE=616907430.435
# ARIMA(4, 6, 0) RMSE=885.971
# ARIMA(4, 6, 1) RMSE=509.554
# ARIMA(4, 6, 2) RMSE=297.372
# LU decomposition error.
# ARIMA(4, 6, 4) RMSE=8076963.237
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(4, 6, 8) RMSE=838.667
# ARIMA(4, 6, 9) RMSE=881.921
# ARIMA(4, 7, 0) RMSE=1477.493
# ARIMA(4, 7, 1) RMSE=962.053
# ARIMA(4, 7, 2) RMSE=630.997
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(4, 7, 8) RMSE=946.088
# ARIMA(4, 7, 9) RMSE=938.794
# ARIMA(4, 8, 0) RMSE=3257.694
# ARIMA(4, 8, 1) RMSE=2014.944
# ARIMA(4, 8, 2) RMSE=1273.008
# ARIMA(4, 8, 3) RMSE=23239668414.619
# ARIMA(4, 8, 4) RMSE=8127150942.647
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# ARIMA(4, 8, 9) RMSE=1662.412
# ARIMA(4, 9, 0) RMSE=5854.383
# ARIMA(4, 9, 1) RMSE=3551.646
# ARIMA(4, 9, 2) RMSE=2334.370
# ARIMA(4, 9, 3) RMSE=517907047574.625
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(4, 9, 7) RMSE=2319.134
# ARIMA(4, 9, 8) RMSE=3438.593
# ARIMA(4, 9, 9) RMSE=4195.383
# ARIMA(5, 0, 0) RMSE=185.008
# ARIMA(5, 0, 1) RMSE=196.807
# ARIMA(5, 0, 2) RMSE=212.074
# ARIMA(5, 0, 3) RMSE=242.452
# LU decomposition error.
# ARIMA(5, 0, 5) RMSE=1115.116
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(5, 1, 0) RMSE=168.255
# ARIMA(5, 1, 1) RMSE=164.868
# ARIMA(5, 1, 2) RMSE=149.891
# ARIMA(5, 1, 3) RMSE=175.378
# ARIMA(5, 1, 4) RMSE=1795.237
# ARIMA(5, 1, 5) RMSE=321.130
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(5, 2, 0) RMSE=173.785
# ARIMA(5, 2, 1) RMSE=158.763
# ARIMA(5, 2, 2) RMSE=160.770
# ARIMA(5, 2, 3) RMSE=205.757
# ARIMA(5, 2, 4) RMSE=1331.064
# ARIMA(5, 2, 5) RMSE=1167.564
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# ARIMA(5, 3, 0) RMSE=234.099
# LU decomposition error.
# LU decomposition error.
# ARIMA(5, 3, 3) RMSE=1482.662
# LU decomposition error.
# ARIMA(5, 3, 5) RMSE=47810.441
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(5, 3, 9) RMSE=3571293.239
# ARIMA(5, 4, 0) RMSE=2376140.990
# ARIMA(5, 4, 1) RMSE=227.470
# ARIMA(5, 4, 2) RMSE=1139197.967
# LU decomposition error.
# LU decomposition error.
# ARIMA(5, 4, 5) RMSE=1375.483
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(5, 4, 9) RMSE=569.958
# ARIMA(5, 5, 0) RMSE=485.848
# ARIMA(5, 5, 1) RMSE=317.928
# ARIMA(5, 5, 2) RMSE=1297.755
# ARIMA(5, 5, 3) RMSE=1333.672
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(5, 5, 9) RMSE=796.374
# ARIMA(5, 6, 0) RMSE=7861445.724
# LU decomposition error.
# ARIMA(5, 6, 2) RMSE=221312918.186
# LU decomposition error.
# ARIMA(5, 6, 4) RMSE=566900522.700
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(5, 6, 8) RMSE=904.043
# ARIMA(5, 6, 9) RMSE=789.257
# ARIMA(5, 7, 0) RMSE=1596.226
# ARIMA(5, 7, 1) RMSE=2770127165.167
# ARIMA(5, 7, 2) RMSE=502.768
# LU decomposition error.
# ARIMA(5, 7, 4) RMSE=880099240.081
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(5, 7, 8) RMSE=848.477
# ARIMA(5, 7, 9) RMSE=963.122
# ARIMA(5, 8, 0) RMSE=2159.621
# ARIMA(5, 8, 1) RMSE=1493.918
# ARIMA(5, 8, 2) RMSE=988.118
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(5, 8, 8) RMSE=1690.413
# ARIMA(5, 8, 9) RMSE=1626.474
# ARIMA(5, 9, 0) RMSE=4340.903
# ARIMA(5, 9, 1) RMSE=2623.244
# ARIMA(5, 9, 2) RMSE=1756.464
# ARIMA(5, 9, 3) RMSE=212806839196.222
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(5, 9, 7) RMSE=2405.576
# ARIMA(5, 9, 8) RMSE=2451.078
# ARIMA(5, 9, 9) RMSE=2434.036
# ARIMA(6, 0, 0) RMSE=187.487
# ARIMA(6, 0, 1) RMSE=193.894
# ARIMA(6, 0, 2) RMSE=217.616
# ARIMA(6, 0, 3) RMSE=271.266
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(6, 1, 0) RMSE=174.705
# ARIMA(6, 1, 1) RMSE=155.976
# ARIMA(6, 1, 2) RMSE=145.748
# ARIMA(6, 1, 3) RMSE=181.650
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(6, 2, 0) RMSE=158.875
# ARIMA(6, 2, 1) RMSE=156.394
# ARIMA(6, 2, 2) RMSE=139.900
# ARIMA(6, 2, 3) RMSE=135.816
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(6, 3, 0) RMSE=1384.803
# LU decomposition error.
# ARIMA(6, 3, 2) RMSE=187.349
# LU decomposition error.
# ARIMA(6, 3, 4) RMSE=20958.536
# ARIMA(6, 3, 5) RMSE=56013.832
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(6, 3, 9) RMSE=297.642
# LU decomposition error.
# LU decomposition error.
# ARIMA(6, 4, 2) RMSE=1522461.908
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(6, 4, 9) RMSE=452.705
# LU decomposition error.
# ARIMA(6, 5, 1) RMSE=1300.703
# ARIMA(6, 5, 2) RMSE=274.670
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(6, 5, 9) RMSE=727.636
# ARIMA(6, 6, 0) RMSE=136872535.916
# LU decomposition error.
# ARIMA(6, 6, 2) RMSE=269.859
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(6, 6, 8) RMSE=869.658
# ARIMA(6, 6, 9) RMSE=861.049
# LU decomposition error.
# ARIMA(6, 7, 1) RMSE=2010264543.460
# ARIMA(6, 7, 2) RMSE=439.718
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(6, 7, 8) RMSE=990.636
# ARIMA(6, 7, 9) RMSE=985.718
# ARIMA(6, 8, 0) RMSE=4551921768.237
# ARIMA(6, 8, 1) RMSE=1280.787
# ARIMA(6, 8, 2) RMSE=923.014
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(6, 8, 8) RMSE=1673.967
# ARIMA(6, 8, 9) RMSE=1753.326
# ARIMA(6, 9, 0) RMSE=3703.505
# ARIMA(6, 9, 1) RMSE=17916644447.214
# ARIMA(6, 9, 2) RMSE=1453.439
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(6, 9, 7) RMSE=2353.394
# ARIMA(6, 9, 8) RMSE=2483.742
# ARIMA(6, 9, 9) RMSE=2393.531
# ARIMA(7, 0, 0) RMSE=206.544
# ARIMA(7, 0, 1) RMSE=209.068
# ARIMA(7, 0, 2) RMSE=207.227
# ARIMA(7, 0, 3) RMSE=266.586
# LU decomposition error.
# LU decomposition error.
# ARIMA(7, 0, 6) RMSE=682.977
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(7, 1, 0) RMSE=173.128
# ARIMA(7, 1, 1) RMSE=153.628
# ARIMA(7, 1, 2) RMSE=154.301
# ARIMA(7, 1, 3) RMSE=186.565
# LU decomposition error.
# ARIMA(7, 1, 5) RMSE=1512.260
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(7, 2, 0) RMSE=178.581
# LU decomposition error.
# ARIMA(7, 2, 2) RMSE=177.540
# ARIMA(7, 2, 3) RMSE=146.702
# ARIMA(7, 2, 4) RMSE=185.274
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# ARIMA(7, 3, 1) RMSE=1354.799
# ARIMA(7, 3, 2) RMSE=182.233
# ARIMA(7, 3, 3) RMSE=222.999
# LU decomposition error.
# ARIMA(7, 3, 5) RMSE=60654.303
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(7, 3, 9) RMSE=355.207
# ARIMA(7, 4, 0) RMSE=1958182.982
# ARIMA(7, 4, 1) RMSE=1257526.975
# ARIMA(7, 4, 2) RMSE=1338.133
# LU decomposition error.
# LU decomposition error.
# ARIMA(7, 4, 5) RMSE=154.207
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(7, 4, 9) RMSE=485.669
# LU decomposition error.
# LU decomposition error.
# ARIMA(7, 5, 2) RMSE=1352.220
# ARIMA(7, 5, 3) RMSE=2634.751
# ARIMA(7, 5, 4) RMSE=69611596.409
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(7, 5, 9) RMSE=735.782
# ARIMA(7, 6, 0) RMSE=79773960.584
# ARIMA(7, 6, 1) RMSE=443115195.810
# ARIMA(7, 6, 2) RMSE=128687731.662
# LU decomposition error.
# ARIMA(7, 6, 4) RMSE=488292074.608
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(7, 6, 8) RMSE=857.720
# ARIMA(7, 6, 9) RMSE=850.625
# ARIMA(7, 7, 0) RMSE=6261807081.162
# LU decomposition error.
# ARIMA(7, 7, 2) RMSE=1252.165
# ARIMA(7, 7, 3) RMSE=1191279041.610
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(7, 7, 8) RMSE=1043.459
# ARIMA(7, 7, 9) RMSE=985.571
# ARIMA(7, 8, 0) RMSE=30568637378.718
# ARIMA(7, 8, 1) RMSE=46982508576.604
# LU decomposition error.
# ARIMA(7, 8, 3) RMSE=4073018866.318
# ARIMA(7, 8, 4) RMSE=19673204599.844
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(7, 8, 8) RMSE=1715.582
# ARIMA(7, 8, 9) RMSE=1684.905
# LU decomposition error.
# LU decomposition error.
# ARIMA(7, 9, 2) RMSE=1503.460
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(7, 9, 7) RMSE=2450.409
# ARIMA(7, 9, 8) RMSE=2624.600
# ARIMA(7, 9, 9) RMSE=2372.683
# LU decomposition error.
# ARIMA(8, 0, 1) RMSE=223.563
# ARIMA(8, 0, 2) RMSE=205.927
# ARIMA(8, 0, 3) RMSE=283.326
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(8, 1, 0) RMSE=175.389
# ARIMA(8, 1, 1) RMSE=174.458
# ARIMA(8, 1, 2) RMSE=182.353
# ARIMA(8, 1, 3) RMSE=197.686
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(8, 2, 0) RMSE=168.778
# ARIMA(8, 2, 1) RMSE=192.559
# ARIMA(8, 2, 2) RMSE=181.311
# ARIMA(8, 2, 3) RMSE=168.603
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# ARIMA(8, 3, 1) RMSE=181.994
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# ARIMA(8, 3, 5) RMSE=72406.665
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(8, 3, 9) RMSE=330.511
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(8, 4, 9) RMSE=480.369
# LU decomposition error.
# LU decomposition error.
# ARIMA(8, 5, 2) RMSE=1251.707
# LU decomposition error.
# ARIMA(8, 5, 4) RMSE=12519753.253
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(8, 5, 9) RMSE=720.125
# LU decomposition error.
# ARIMA(8, 6, 1) RMSE=75472661.370
# LU decomposition error.
# LU decomposition error.
# ARIMA(8, 6, 4) RMSE=133410793.885
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(8, 6, 8) RMSE=859.250
# ARIMA(8, 6, 9) RMSE=838.541
# ARIMA(8, 7, 0) RMSE=133602554.410
# LU decomposition error.
# ARIMA(8, 7, 2) RMSE=561.627
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(8, 7, 8) RMSE=962.063
# ARIMA(8, 7, 9) RMSE=997.766
# LU decomposition error.
# ARIMA(8, 8, 1) RMSE=7112610743.520
# LU decomposition error.
# ARIMA(8, 8, 3) RMSE=36233072175582.500
# ARIMA(8, 8, 4) RMSE=19266600992.787
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(8, 8, 8) RMSE=1651.221
# ARIMA(8, 8, 9) RMSE=1711.738
# ARIMA(8, 9, 0) RMSE=650958185774.792
# ARIMA(8, 9, 1) RMSE=20542210651.467
# LU decomposition error.
# ARIMA(8, 9, 3) RMSE=743662919317.861
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(8, 9, 7) RMSE=2793.775
# ARIMA(8, 9, 8) RMSE=2506.651
# ARIMA(8, 9, 9) RMSE=2489.190
# ARIMA(9, 0, 0) RMSE=218.327
# ARIMA(9, 0, 1) RMSE=242.943
# ARIMA(9, 0, 2) RMSE=236.853
# ARIMA(9, 0, 3) RMSE=257.992
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(9, 1, 0) RMSE=160.150
# ARIMA(9, 1, 1) RMSE=200.765
# ARIMA(9, 1, 2) RMSE=185.609
# ARIMA(9, 1, 3) RMSE=200.046
# ARIMA(9, 1, 4) RMSE=1366.194
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# ARIMA(9, 2, 3) RMSE=195.567
# LU decomposition error.
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(9, 3, 0) RMSE=1263.333
# LU decomposition error.
# ARIMA(9, 3, 2) RMSE=1355.762
# LU decomposition error.
# LU decomposition error.
# ARIMA(9, 3, 5) RMSE=72406.665
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(9, 3, 9) RMSE=340.850
# ARIMA(9, 4, 0) RMSE=354131.640
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# ARIMA(9, 4, 4) RMSE=137567.983
# ARIMA(9, 4, 5) RMSE=149.851
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(9, 4, 9) RMSE=493.140
# LU decomposition error.
# ARIMA(9, 5, 1) RMSE=6818065.269
# LU decomposition error.
# ARIMA(9, 5, 3) RMSE=14260777.226
# ARIMA(9, 5, 4) RMSE=11315590.694
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(9, 5, 9) RMSE=741.492
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# ARIMA(9, 6, 4) RMSE=18845629.373
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(9, 6, 8) RMSE=850.900
# ARIMA(9, 6, 9) RMSE=848.216
# ARIMA(9, 7, 0) RMSE=8487841201.554
# LU decomposition error.
# LU decomposition error.
# LU decomposition error.
# ARIMA(9, 7, 4) RMSE=1885829346.119
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(9, 7, 8) RMSE=984.985
# ARIMA(9, 7, 9) RMSE=984.318
# ARIMA(9, 8, 0) RMSE=5837510094.895
# ARIMA(9, 8, 1) RMSE=5034436542.641
# ARIMA(9, 8, 2) RMSE=18413608270653.707
# ARIMA(9, 8, 3) RMSE=3887807756.512
# ARIMA(9, 8, 4) RMSE=19420129946.156
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(9, 8, 8) RMSE=1678.482
# ARIMA(9, 8, 9) RMSE=1701.838
# ARIMA(9, 9, 0) RMSE=726857907128.094
# ARIMA(9, 9, 1) RMSE=30809296603.497
# ARIMA(9, 9, 2) RMSE=30809296863.637
# LU decomposition error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# Schur decomposition solver error.
# ARIMA(9, 9, 7) RMSE=2504.098
# ARIMA(9, 9, 8) RMSE=2393.189
# ARIMA(9, 9, 9) RMSE=2404.642
# Best ARIMA(4, 4, 5) RMSE=124.738

# %% [markdown]
# Best ARIMA(4, 4, 5) RMSE=124.738

# %%
# save finalized model to file
from pandas import read_csv
from statsmodels.tsa.arima.model import ARIMA

# %%
# load data
train = read_csv('dataset.csv', index_col=0, parse_dates=True)
# prepare data
X = train.values
X = X.astype('float32')

# %%
train
# Out:
#        1734.8269996643066
# Q1_86
# Q2_86         2244.960999
# Q3_86         2533.804993
# Q4_86         2154.962997
# Q1_87         1547.818996
# Q2_87         2104.411995
# Q3_87         2014.362999
# Q4_87         1991.746998
# Q1_88         1869.049999
# Q2_88         2313.631996
# Q3_88         2128.320000
# Q4_88         2026.828999
# Q1_89         1910.603996
# Q2_89         2331.164993
# Q3_89         2206.549995
# Q4_89         2173.967995
# Q1_90         2148.278000
# Q2_90         2739.307999
# Q3_90         2792.753998
# Q4_90         2556.009995
# Q1_91         2480.973999
# Q2_91         3039.522995
# Q3_91         3172.115997
# Q4_91         2879.000999
# Q1_92         2772.000000
# Q2_92         3550.000000
# Q3_92         3508.000000
# Q4_92         3243.859993
# Q1_93         3056.000000
# Q2_93         3899.000000
# Q3_93         3629.000000
# Q4_93         3373.000000

# %%
len(X),X
# Out:
# (31,
#  array([[2244.961 ],
#         [2533.805 ],
#         [2154.963 ],
#         [1547.819 ],
#         [2104.412 ],
#         [2014.363 ],
#         [1991.747 ],
#         [1869.05  ],
#         [2313.632 ],
#         [2128.32  ],
#         [2026.829 ],
#         [1910.604 ],
#         [2331.165 ],
#         [2206.55  ],
#         [2173.968 ],
#         [2148.278 ],
#         [2739.308 ],
#         [2792.754 ],
#         [2556.01  ],
#         [2480.9739],
#         [3039.523 ],
#         [3172.116 ],
#         [2879.001 ],
#         [2772.    ],
#         [3550.    ],
#         [3508.    ],
#         [3243.86  ],
#         [3056.    ],
#         [3899.    ],
#         [3629.    ],
#         [3373.    ]], dtype=float32))

# %%
train.values
# Out:
# array([[2244.96099854],
#        [2533.80499268],
#        [2154.96299744],
#        [1547.81899643],
#        [2104.41199493],
#        [2014.36299896],
#        [1991.74699783],
#        [1869.04999924],
#        [2313.63199615],
#        [2128.31999969],
#        [2026.82899857],
#        [1910.60399628],
#        [2331.16499329],
#        [2206.54999542],
#        [2173.96799469],
#        [2148.27799988],
#        [2739.30799866],
#        [2792.7539978 ],
#        [2556.00999451],
#        [2480.97399902],
#        [3039.522995  ],
#        [3172.11599731],
#        [2879.00099945],
#        [2772.        ],
#        [3550.        ],
#        [3508.        ],
#        [3243.85999298],
#        [3056.        ],
#        [3899.        ],
#        [3629.        ],
#        [3373.        ]])

# %%
# fit model
model = ARIMA(train.values, order=(4,4,5))
model_fit = model.fit()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   31
# Model:                 ARIMA(4, 4, 5)   Log Likelihood                   0.000
# Date:                Fri, 16 Dec 2022   AIC                             20.000
# Time:                        23:18:33   BIC                             32.958
# Sample:                             0   HQIC                            23.853
#                                  - 31
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -2.2638      0.069    -32.738      0.000      -2.399      -2.128
# ar.L2         -2.5315         -0        inf      0.000      -2.531      -2.531
# ar.L3         -2.2624      0.101    -22.305      0.000      -2.461      -2.064
# ar.L4         -0.9947         -0        inf      0.000      -0.995      -0.995
# ma.L1         -1.3529         -0        inf      0.000      -1.353      -1.353
# ma.L2         -0.9412         -0        inf      0.000      -0.941      -0.941
# ma.L3          0.9412         -0       -inf      0.000       0.941       0.941
# ma.L4          1.3529         -0       -inf      0.000       1.353       1.353
# ma.L5         -1.0000         -0        inf      0.000      -1.000      -1.000
# sigma2      1.797e+05         -0       -inf      0.000     1.8e+05     1.8e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                    nan   Jarque-Bera (JB):                10.12
# Prob(Q):                               nan   Prob(JB):                         0.01
# Heteroskedasticity (H):                nan   Skew:                             0.00
# Prob(H) (two-sided):                   nan   Kurtosis:                         0.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number    inf. Standard errors may be unstable.
# """

# %%
forecast=model_fit.forecast(steps=10)[0]

# %%
model_fit.get_forecast()

# %%
# Plotting Residual Errors
plt.rcParams.update({'figure.figsize' : (9,3), 'figure.dpi' : 120})  

myresiduals = pd.DataFrame(model_fit.resid)  
fig, ax = plt.subplots(1,2)  
myresiduals.plot(title = "Residuals", ax = ax[0])  
myresiduals.plot(kind = 'kde', title = 'Density', ax = ax[1])  
plt.show()
