# %% [markdown]
# # Time Forecasting ( Airlines Passengers )

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
print(open("Problem_statement.txt").read())
# Out:
# Forecast the CocaCola prices and Airlines Passengers data set. Prepare a document for each model explaining
# how many dummy variables you have created and RMSE value for each model. Finally which model you will use for
# Forecasting.

# %%
data = pd.read_excel('Airlines+Data.xlsx')
data
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306
#
# [96 rows x 2 columns]

# %%
data.shape
# Out:
# (96, 2)

# %%
96/12
# Out:
# 8.0

# %%
indexedData = data.set_index(['Month'])
indexedData
# Out:
#             Passengers
# Month
# 1995-01-01         112
# 1995-02-01         118
# 1995-03-01         132
# 1995-04-01         129
# 1995-05-01         121
# ...                ...
# 2002-08-01         405
# 2002-09-01         355
# 2002-10-01         306
# 2002-11-01         271
# 2002-12-01         306
#
# [96 rows x 1 columns]

# %%
plt.figure(figsize= (10,6))
plt.xlabel("Date")
plt.ylabel("Number of air passengers")
plt.plot(indexedData)

# %% [markdown]
# #### Determining optimal window size for moving statistics

# %%
plt.figure(figsize=(12,4))
data.Passengers.plot(label="org")
plt.title("original series")

for i in range(2,25):                       # to find optimal windaow size
    plt.figure(figsize=(12,4))
     
    indexedData.rolling(i).mean().plot(label=str(i))     # roling is nothing but moving average
    plt.title("MA "+str(i))
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# By seeing the above plots we can clearly say that optimal window size is 12

# %% [markdown]
# ### Determining Moving statistics

# %%
rolmean = indexedData.rolling(window=12).mean()
rolstd = indexedData.rolling(window=12).std()
print(rolmean, rolstd)
# Out:
#             Passengers
# Month
# 1995-01-01         NaN
# 1995-02-01         NaN
# 1995-03-01         NaN
# 1995-04-01         NaN
# 1995-05-01         NaN
# ...                ...
# 2002-08-01  316.833333
# 2002-09-01  320.416667
# 2002-10-01  323.083333
# 2002-11-01  325.916667
# 2002-12-01  328.250000
#
# [96 rows x 1 columns]             Passengers
# Month
# 1995-01-01         NaN
# 1995-02-01         NaN
# 1995-03-01         NaN
# 1995-04-01         NaN
# 1995-05-01         NaN
# ...                ...
# 2002-08-01   54.530781
# 2002-09-01   55.586883
# 2002-10-01   53.899668
# 2002-11-01   49.692616
# 2002-12-01   47.861780
#
# [96 rows x 1 columns]

# %%
#Plot rolling statistics:
plt.figure(figsize= (10,6))
orig = plt.plot(indexedData, color='blue',label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %% [markdown]
# ### Augmented Dickey-Fuller test:

# %%
from statsmodels.tsa.stattools import adfuller

print ('Results of Dickey-Fuller Test:')
dftest = adfuller(indexedData, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  1.340248
# p-value                         0.996825
# #Lags Used                     12.000000
# Number of Observations Used    83.000000
# Critical Value (1%)            -3.511712
# Critical Value (5%)            -2.897048
# Critical Value (10%)           -2.585713
# dtype: float64

# %% [markdown]
# p_value is heigh therefore it is not a stationary data

# %% [markdown]
# Therefore we go for Data based techniques

# %% [markdown]
# #### Logscale

# %%
# Estimating trend
indexedDataset_logScale = np.log(indexedData)
plt.plot(indexedDataset_logScale)

# %% [markdown]
# ### Seasonal Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(indexedDataset_logScale)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(10,8))
plt.subplot(411)
plt.plot(indexedDataset_logScale, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='upper left')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='upper left')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='upper left')
plt.tight_layout()

# %% [markdown]
# ### Splitting the data into Training and Testing

# %%
train = data.head(84)
test = data.tail(12)

# %%
train
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 79 2001-08-01         347
# 80 2001-09-01         312
# 81 2001-10-01         274
# 82 2001-11-01         237
# 83 2001-12-01         278
#
# [84 rows x 2 columns]

# %%
test
# Out:
#         Month  Passengers
# 84 2002-01-01         284
# 85 2002-02-01         277
# 86 2002-03-01         317
# 87 2002-04-01         313
# 88 2002-05-01         318
# 89 2002-06-01         374
# 90 2002-07-01         413
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306

# %% [markdown]
# #### Mean actual Predicted Error ( MAPE value )

# %%
def MAPE(org,pred):
    temp = np.abs((pred-org)/org)*100
    return np.mean(temp)

# %% [markdown]
# ### Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing # SES
from statsmodels.tsa.holtwinters import Holt # Holts Exponential Smoothing # double exponential
from statsmodels.tsa.holtwinters import ExponentialSmoothing  # triple exponential

# %% [markdown]
# #### HYperparameter tunning for smoothing_level

# %%
import numpy as np
x=np.linspace(0.1,1,20)
for i in x :
    ses_model = SimpleExpSmoothing(train["Passengers"]).fit(smoothing_level=i)
    pred_ses = ses_model.predict(start = test.index[0],end = test.index[-1])
    score=MAPE(test.Passengers, pred_ses) 
    print("smoothing_level ",i,"-->","MAPE Error",score)
# Out:
# smoothing_level  0.1 --> MAPE Error 15.81327881103257
# smoothing_level  0.1473684210526316 --> MAPE Error 13.998308786798612
# smoothing_level  0.19473684210526315 --> MAPE Error 13.43875758983704
# smoothing_level  0.24210526315789474 --> MAPE Error 13.361780244106626
# smoothing_level  0.2894736842105263 --> MAPE Error 13.557114617029564
# smoothing_level  0.33684210526315794 --> MAPE Error 13.895321792313554
# smoothing_level  0.38421052631578945 --> MAPE Error 14.289593448209663
# smoothing_level  0.43157894736842106 --> MAPE Error 14.76306690519897
# smoothing_level  0.4789473684210527 --> MAPE Error 15.224824028669062
# smoothing_level  0.5263157894736842 --> MAPE Error 15.600944301455975
# smoothing_level  0.5736842105263158 --> MAPE Error 15.874993628428266
# smoothing_level  0.6210526315789474 --> MAPE Error 16.071640221230833
# smoothing_level  0.6684210526315789 --> MAPE Error 16.145012862053974
# smoothing_level  0.7157894736842105 --> MAPE Error 16.091775475637615
# smoothing_level  0.7631578947368421 --> MAPE Error 15.922226635356502
# smoothing_level  0.8105263157894737 --> MAPE Error 15.701477251725604
# smoothing_level  0.8578947368421053 --> MAPE Error 15.407992901863096
# smoothing_level  0.9052631578947369 --> MAPE Error 15.05016692286267
# smoothing_level  0.9526315789473684 --> MAPE Error 14.63669999118891
# smoothing_level  1.0 --> MAPE Error 14.235433039401634

# %% [markdown]
# Best MAPE value is for smoothing_level = 0.24

# %% [markdown]
# #### Model

# %%
ses_model = SimpleExpSmoothing(train["Passengers"]).fit(smoothing_level=0.24)
pred_ses = ses_model.predict(start = test.index[0], end = test.index[-1])
MAPE(test.Passengers, pred_ses)
# Out:
# 13.358245180077153

# %%
pred_ses
# Out:
# 84    282.651011
# 85    282.651011
# 86    282.651011
# 87    282.651011
# 88    282.651011
# 89    282.651011
# 90    282.651011
# 91    282.651011
# 92    282.651011
# 93    282.651011
# 94    282.651011
# 95    282.651011
# dtype: float64

# %% [markdown]
# ###  Holts Exponential Smoothing Model or Double exponential Model

# %% [markdown]
# #### Hyperparameter tunning for smoothing_level and smoothing_trend

# %%
import numpy as np
alphas=np.arange(0.1,1,0.9/10)
betas=np.arange(0.1,1,0.9/10)
l=[]
for i in alphas :
    for j in betas:
        hw_model = Holt(train["Passengers"]).fit(smoothing_level=i, smoothing_trend=j)
        print(hw_model)
        pred_hw = hw_model.predict(start = test.index[0],end = test.index[-1])
        score=MAPE(pred_hw,test.Passengers)
        print("smoothing_level ",i," smoothing_slope",j,"-->","MAPE Error",score)
        l.append((i,j,score))
# Out:
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD2310>
# smoothing_level  0.1  smoothing_slope 0.1 --> MAPE Error 11.825704431181222
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF490>
# smoothing_level  0.1  smoothing_slope 0.19 --> MAPE Error 10.985095982050025
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDFD30>
# smoothing_level  0.1  smoothing_slope 0.28 --> MAPE Error 11.308431992970638
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD2250>
# smoothing_level  0.1  smoothing_slope 0.37 --> MAPE Error 11.748306843904194
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF3D0>
# smoothing_level  0.1  smoothing_slope 0.45999999999999996 --> MAPE Error 12.004590397121015
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2D00>
# smoothing_level  0.1  smoothing_slope 0.5499999999999999 --> MAPE Error 12.027792542515442
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF1C0>
# smoothing_level  0.1  smoothing_slope 0.64 --> MAPE Error 11.82973525777463
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF7F0>
# smoothing_level  0.1  smoothing_slope 0.73 --> MAPE Error 11.538472607086035
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2F70>
# smoothing_level  0.1  smoothing_slope 0.82 --> MAPE Error 11.309105000920068
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A7099940>
# smoothing_level  0.1  smoothing_slope 0.9099999999999999 --> MAPE Error 11.414437359201303
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD21F0>
# smoothing_level  0.19  smoothing_slope 0.1 --> MAPE Error 11.506480545716633
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2E20>
# smoothing_level  0.19  smoothing_slope 0.19 --> MAPE Error 11.057273727732083
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD20A0>
# smoothing_level  0.19  smoothing_slope 0.28 --> MAPE Error 11.166572924325378
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2FD0>
# smoothing_level  0.19  smoothing_slope 0.37 --> MAPE Error 11.67956783633351
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFAD30>
# smoothing_level  0.19  smoothing_slope 0.45999999999999996 --> MAPE Error 14.929361180375727
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFAE50>
# smoothing_level  0.19  smoothing_slope 0.5499999999999999 --> MAPE Error 19.588762904209556
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF220>
# smoothing_level  0.19  smoothing_slope 0.64 --> MAPE Error 27.525994679493337
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A7099940>
# smoothing_level  0.19  smoothing_slope 0.73 --> MAPE Error 41.67943313236868
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8520>
# smoothing_level  0.19  smoothing_slope 0.82 --> MAPE Error 72.61605550795417
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFAFA0>
# smoothing_level  0.19  smoothing_slope 0.9099999999999999 --> MAPE Error 199.8266877656861
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA580>
# smoothing_level  0.28  smoothing_slope 0.1 --> MAPE Error 12.299180589689728
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70E1C70>
# smoothing_level  0.28  smoothing_slope 0.19 --> MAPE Error 13.063468625611934
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFABE0>
# smoothing_level  0.28  smoothing_slope 0.28 --> MAPE Error 17.804005411050237
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F89D0>
# smoothing_level  0.28  smoothing_slope 0.37 --> MAPE Error 28.570997746294186
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA580>
# smoothing_level  0.28  smoothing_slope 0.45999999999999996 --> MAPE Error 48.072123119724516
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8730>
# smoothing_level  0.28  smoothing_slope 0.5499999999999999 --> MAPE Error 93.50431269975063
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA130>
# smoothing_level  0.28  smoothing_slope 0.64 --> MAPE Error 483.04305661292483
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70E1D60>
# smoothing_level  0.28  smoothing_slope 0.73 --> MAPE Error 695.3340757340412
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFACA0>
# smoothing_level  0.28  smoothing_slope 0.82 --> MAPE Error 604.2551084787507
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8730>
# smoothing_level  0.28  smoothing_slope 0.9099999999999999 --> MAPE Error 548.9286656031513
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A82A18E0>
# smoothing_level  0.37  smoothing_slope 0.1 --> MAPE Error 14.423208933639705
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70E1E50>
# smoothing_level  0.37  smoothing_slope 0.19 --> MAPE Error 19.62788600009085
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2700>
# smoothing_level  0.37  smoothing_slope 0.28 --> MAPE Error 33.991871987357655
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA220>
# smoothing_level  0.37  smoothing_slope 0.37 --> MAPE Error 62.45881895208783
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2130>
# smoothing_level  0.37  smoothing_slope 0.45999999999999996 --> MAPE Error 131.24904296564648
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70E1D60>
# smoothing_level  0.37  smoothing_slope 0.5499999999999999 --> MAPE Error 624.0767671056592
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A82A23D0>
# smoothing_level  0.37  smoothing_slope 0.64 --> MAPE Error 764.303168111433
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD2250>
# smoothing_level  0.37  smoothing_slope 0.73 --> MAPE Error 1611.4654749095928
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD2340>
# smoothing_level  0.37  smoothing_slope 0.82 --> MAPE Error 681.5216098310477
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF9A0>
# smoothing_level  0.37  smoothing_slope 0.9099999999999999 --> MAPE Error 707.1666661399058
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8FA0>
# smoothing_level  0.45999999999999996  smoothing_slope 0.1 --> MAPE Error 17.743056524920856
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD2100>
# smoothing_level  0.45999999999999996  smoothing_slope 0.19 --> MAPE Error 28.54989339819389
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8A90>
# smoothing_level  0.45999999999999996  smoothing_slope 0.28 --> MAPE Error 51.29742280121027
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF21F0>
# smoothing_level  0.45999999999999996  smoothing_slope 0.37 --> MAPE Error 95.73513200128504
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70E1F40>
# smoothing_level  0.45999999999999996  smoothing_slope 0.45999999999999996 --> MAPE Error 211.59205862024842
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8730>
# smoothing_level  0.45999999999999996  smoothing_slope 0.5499999999999999 --> MAPE Error 702.9338137914018
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70E1D60>
# smoothing_level  0.45999999999999996  smoothing_slope 0.64 --> MAPE Error 1304.6760219000846
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2640>
# smoothing_level  0.45999999999999996  smoothing_slope 0.73 --> MAPE Error 858.3266250716941
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF9A0>
# smoothing_level  0.45999999999999996  smoothing_slope 0.82 --> MAPE Error 3776.8982474915333
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF760>
# smoothing_level  0.45999999999999996  smoothing_slope 0.9099999999999999 --> MAPE Error 826.9360165838916
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2D30>
# smoothing_level  0.5499999999999999  smoothing_slope 0.1 --> MAPE Error 20.526337910957704
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8A90>
# smoothing_level  0.5499999999999999  smoothing_slope 0.19 --> MAPE Error 34.812964251527035
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2100>
# smoothing_level  0.5499999999999999  smoothing_slope 0.28 --> MAPE Error 60.49417424127939
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF27F0>
# smoothing_level  0.5499999999999999  smoothing_slope 0.37 --> MAPE Error 103.17959650380526
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA310>
# smoothing_level  0.5499999999999999  smoothing_slope 0.45999999999999996 --> MAPE Error 171.581954474383
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF28E0>
# smoothing_level  0.5499999999999999  smoothing_slope 0.5499999999999999 --> MAPE Error 262.0019313998129
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70E1DF0>
# smoothing_level  0.5499999999999999  smoothing_slope 0.64 --> MAPE Error 285.2010178940706
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA8E0>
# smoothing_level  0.5499999999999999  smoothing_slope 0.73 --> MAPE Error 213.07641001606785
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2610>
# smoothing_level  0.5499999999999999  smoothing_slope 0.82 --> MAPE Error 144.82577868988528
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA280>
# smoothing_level  0.5499999999999999  smoothing_slope 0.9099999999999999 --> MAPE Error 96.52955732885617
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A84D5970>
# smoothing_level  0.64  smoothing_slope 0.1 --> MAPE Error 22.2156715433625
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA190>
# smoothing_level  0.64  smoothing_slope 0.19 --> MAPE Error 36.9006844033352
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA940>
# smoothing_level  0.64  smoothing_slope 0.28 --> MAPE Error 59.593462774872
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD21F0>
# smoothing_level  0.64  smoothing_slope 0.37 --> MAPE Error 87.66627246870983
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD2220>
# smoothing_level  0.64  smoothing_slope 0.45999999999999996 --> MAPE Error 110.77986519743672
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFAD00>
# smoothing_level  0.64  smoothing_slope 0.5499999999999999 --> MAPE Error 113.6931393626394
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF250>
# smoothing_level  0.64  smoothing_slope 0.64 --> MAPE Error 95.78744164332021
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFAC10>
# smoothing_level  0.64  smoothing_slope 0.73 --> MAPE Error 70.2054879363928
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2BE0>
# smoothing_level  0.64  smoothing_slope 0.82 --> MAPE Error 45.97773955970152
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD2130>
# smoothing_level  0.64  smoothing_slope 0.9099999999999999 --> MAPE Error 25.781520338069143
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA820>
# smoothing_level  0.73  smoothing_slope 0.1 --> MAPE Error 22.27299742735185
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF24F0>
# smoothing_level  0.73  smoothing_slope 0.19 --> MAPE Error 35.33831795047538
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2CA0>
# smoothing_level  0.73  smoothing_slope 0.28 --> MAPE Error 52.00616663545873
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70E1FA0>
# smoothing_level  0.73  smoothing_slope 0.37 --> MAPE Error 65.99057221581262
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2370>
# smoothing_level  0.73  smoothing_slope 0.45999999999999996 --> MAPE Error 69.27284597449291
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A82A18E0>
# smoothing_level  0.73  smoothing_slope 0.5499999999999999 --> MAPE Error 59.896844510082026
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2A60>
# smoothing_level  0.73  smoothing_slope 0.64 --> MAPE Error 43.592062052207204
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFA1C0>
# smoothing_level  0.73  smoothing_slope 0.73 --> MAPE Error 26.373000352483803
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70E1BE0>
# smoothing_level  0.73  smoothing_slope 0.82 --> MAPE Error 15.802634095814776
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8A90>
# smoothing_level  0.73  smoothing_slope 0.9099999999999999 --> MAPE Error 12.065807639038553
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8F10>
# smoothing_level  0.82  smoothing_slope 0.1 --> MAPE Error 20.99692827527566
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8FD0>
# smoothing_level  0.82  smoothing_slope 0.19 --> MAPE Error 31.399024413314976
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2B20>
# smoothing_level  0.82  smoothing_slope 0.28 --> MAPE Error 41.88020809133821
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F84C0>
# smoothing_level  0.82  smoothing_slope 0.37 --> MAPE Error 46.52300718950227
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2A30>
# smoothing_level  0.82  smoothing_slope 0.45999999999999996 --> MAPE Error 42.06599442413664
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF24C0>
# smoothing_level  0.82  smoothing_slope 0.5499999999999999 --> MAPE Error 30.81159372375943
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8F10>
# smoothing_level  0.82  smoothing_slope 0.64 --> MAPE Error 18.41483673518987
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70C1AC0>
# smoothing_level  0.82  smoothing_slope 0.73 --> MAPE Error 12.793624817264314
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2940>
# smoothing_level  0.82  smoothing_slope 0.82 --> MAPE Error 12.143162448739309
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDFD00>
# smoothing_level  0.82  smoothing_slope 0.9099999999999999 --> MAPE Error 15.64268592786666
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2790>
# smoothing_level  0.9099999999999999  smoothing_slope 0.1 --> MAPE Error 19.19970118826419
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF520>
# smoothing_level  0.9099999999999999  smoothing_slope 0.19 --> MAPE Error 26.28945183351267
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2550>
# smoothing_level  0.9099999999999999  smoothing_slope 0.28 --> MAPE Error 31.714766918328053
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF2790>
# smoothing_level  0.9099999999999999  smoothing_slope 0.37 --> MAPE Error 30.919608515180016
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF26A0>
# smoothing_level  0.9099999999999999  smoothing_slope 0.45999999999999996 --> MAPE Error 23.599692341998523
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A70F8310>
# smoothing_level  0.9099999999999999  smoothing_slope 0.5499999999999999 --> MAPE Error 14.754722544975506
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FDF8E0>
# smoothing_level  0.9099999999999999  smoothing_slope 0.64 --> MAPE Error 11.488890312527113
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FFAD60>
# smoothing_level  0.9099999999999999  smoothing_slope 0.73 --> MAPE Error 12.266804264655704
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FF24F0>
# smoothing_level  0.9099999999999999  smoothing_slope 0.82 --> MAPE Error 17.23869157451528
# <statsmodels.tsa.holtwinters.results.HoltWintersResultsWrapper object at 0x000002C8A6FD22E0>
# smoothing_level  0.9099999999999999  smoothing_slope 0.9099999999999999 --> MAPE Error 24.25379208264052

# %%
a=pd.DataFrame(l,columns=["smoothing_level","smoothing_slope","score"])
a.sort_values(["score"])
# Out:
#     smoothing_level  smoothing_slope        score
# 1              0.10             0.19    10.985096
# 11             0.19             0.19    11.057274
# 12             0.19             0.28    11.166573
# 2              0.10             0.28    11.308432
# 8              0.10             0.82    11.309105
# ..              ...              ...          ...
# 49             0.46             0.91   826.936017
# 47             0.46             0.73   858.326625
# 46             0.46             0.64  1304.676022
# 37             0.37             0.73  1611.465475
# 48             0.46             0.82  3776.898247
#
# [100 rows x 3 columns]

# %% [markdown]
# Best MAPE score is 10.98
# for smopthing_level = 0.1 and
# smoothing_slope = 0.19

# %% [markdown]
# #### Model

# %%
# Holt method 
hw_model = Holt(train["Passengers"]).fit(smoothing_level=0.1, smoothing_trend=0.19)
pred_hw = hw_model.predict(start = test.index[0],end = test.index[-1])
MAPE(pred_hw,test.Passengers)
# Out:
# 10.985095982050025

# %%
pred_hw
# Out:
# 84    302.762441
# 85    306.732180
# 86    310.701918
# 87    314.671656
# 88    318.641395
# 89    322.611133
# 90    326.580872
# 91    330.550610
# 92    334.520348
# 93    338.490087
# 94    342.459825
# 95    346.429564
# dtype: float64

# %% [markdown]
# ### Holts winter exponential smoothing with additive seasonality and additive trend or  triple exponential

# %%
hwe_model_add_add = ExponentialSmoothing(train["Passengers"],seasonal="add",trend="add",seasonal_periods=12).fit() #add the trend to the model
pred_hwe_add_add = hwe_model_add_add.predict(start = test.index[0],end = test.index[-1])

# %%
MAPE(pred_hwe_add_add,test.Passengers)
# Out:
# 6.3810253704201285

# %%
pred_hwe_add_add
# Out:
# 84    280.939322
# 85    281.797440
# 86    309.084255
# 87    302.940944
# 88    302.228123
# 89    326.227614
# 90    351.227032
# 91    350.367844
# 92    325.225143
# 93    300.079066
# 94    276.793799
# 95    301.078915
# dtype: float64

# %% [markdown]
# For all the above 3 models

# %% [markdown]
# triple exponential model is giving less error i,e MAPE score is less for this model

# %% [markdown]
# #### Building a Model for whole data and predicting the next years values

# %%
hwe_model_add_add = ExponentialSmoothing(data["Passengers"],seasonal="add",trend="add",seasonal_periods=12).fit()

# %%
#Forecasting for next 10 time periods
new=hwe_model_add_add.forecast(10)
df=pd.DataFrame(new, columns= ["Passengers"])
df
# Out:
#      Passengers
# 96   319.235270
# 97   311.528386
# 98   350.278691
# 99   346.984976
# 100  351.845022
# 101  403.925707
# 102  440.566797
# 103  427.446477
# 104  376.628169
# 105  329.767502

# %% [markdown]
# predicted No. of Passengers for the year 2003

# %%
plt.figure(figsize= (15,8))
plt.xlabel("Date")
plt.ylabel("Number of air passengers")
plt.plot(data["Passengers"], label="Actual")
plt.plot(df["Passengers"], label="Forecast")
plt.legend(loc='upper left', fontsize=12)
plt.show()

# %% [markdown]
# Forecasted data for the year 2003. is ploted in the above graph
